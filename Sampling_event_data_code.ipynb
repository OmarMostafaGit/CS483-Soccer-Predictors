# %%
import pandas as pd

input_file = "events.csv"
output_file = "events_sampledata.csv"

df = pd.read_csv(input_file, engine="python", on_bad_lines="skip")

sample_df = df.iloc[::7]

sample_df.to_csv(output_file, index=False)
